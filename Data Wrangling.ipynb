# %%
import pandas as pd
import json

# %%
# Open the JSON file
with open('albums_0-999.json', 'r') as file:
    # Read the contents
    json_data = file.read()
    # Parse the JSON
    albums = json.loads(json_data)

# %%
# Open the JSON file
with open('artists_0-999.json', 'r') as file:
    # Read the contents
    json_data = file.read()
    # Parse the JSON
    artists = json.loads(json_data)

# %%
# Open the JSON file
with open('mpd.slice.0-999.json', 'r') as file:
    # Read the contents
    json_data = file.read()
    # Parse the JSON
    mpd = json.loads(json_data)

# %%
# Open the JSON file
with open('songs_0-999.json', 'r') as file:
    # Read the contents
    json_data = file.read()
    # Parse the JSON
    songs = json.loads(json_data)

# %%
songs['0UaMYEvWZi0ZqiDOoHU3YI']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#     'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#     'id': '2wIVse2owClT7go1WT98tk',
#     'name': 'Missy Elliott',
#     'type': 'artist',
#     'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
# ...

# %%
artists['2wIVse2owClT7go1WT98tk']
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#  'followers': {'href': None, 'total': 2386591},
#  'genres': ['dance pop',
#   'hip hop',
#   'hip pop',
#   'neo soul',
#   'pop rap',
#   'r&b',
#   'rap',
#   'urban contemporary',
#   'virginia hip hop'],
#  'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#  'id': '2wIVse2owClT7go1WT98tk',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebf6691f40d906f097e9fbaa4c',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174f6691f40d906f097e9fbaa4c',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178f6691f40d906f097e9fbaa4c',
#    'width': 160}],
#  'name': 'Missy Elliott',
#  'popularity': 70,
#  'type': 'artist',
#  'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}

# %%
albums['6vV5UrXcfyQD1wu4Qo2I9K']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#    'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#    'id': '2wIVse2owClT7go1WT98tk',
#    'name': 'Missy Elliott',
#    'type': 'artist',
#    'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
mpd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12468\2825224975.py in <module>
# ----> 1 mpd[0]
#
# KeyError: 0
